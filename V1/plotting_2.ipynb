# %%
import os 
import seaborn as sns
import matplotlib.pyplot as plt 
import csv 
import pandas as pd 

csv_dir = '../Mosdepth/'
output2_file = 'combined_raw.csv'
dataframes = []

for csv_file in os.listdir(csv_dir):
    if csv_file.endswith('.mosdepth.global.dist.txt'):
        file_path = os.path.join(csv_dir, csv_file)
        df = pd.read_csv(file_path, names=['GeneID', 'Coverage', 'Location'], sep='\t')
        df['source_file'] = os.path.splitext(csv_file)[0].split('.')[0]
        dataframes.append(df)

combined_df = pd.concat(dataframes, axis=0)
combined_df.to_csv(output2_file, index=False, sep='\t', quoting=csv.QUOTE_NONE, escapechar=' ')

plot_data = pd.read_csv('combined_raw.csv', sep='\t', usecols=['GeneID', 'Coverage', 'Location', 'source_file'])

plot_data['GeneID'] = pd.Categorical(plot_data['GeneID'], ordered=True)
num_genes = plot_data['GeneID'].nunique()
num_cols = 5
num_rows = -(-num_genes // num_cols)

g = sns.FacetGrid(plot_data, col='GeneID', hue='source_file', height=4, aspect=1.5, col_wrap=num_cols)
g.map_dataframe(sns.lineplot, x='Location', y='Coverage')
g.add_legend()

plt.show()

# %%
import os 
import seaborn as sns 
import matplotlib.pyplot as plt
import csv 
import pandas as pd 
filter_code="Tb927.3.4350"
data = pd.read_csv('../Mosdepth/ERR9695748.mosdepth.global.dist.txt', sep='\t', header=None, usecols=[0, 1, 2])
filtered_data = data[data[0]==filter_code]
filtered_data.columns = ['Gene', 'Y_values', 'X_values']
sns.lineplot(x='X_values', y='Y_values', data=filtered_data)
plt.show()
plt.xlabel("Normalised gene length")
plt.ylabel("Covergae")
# Out:
# Text(0, 0.5, 'Covergae')

# %%
pip install os
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# WARNING: You are using pip version 21.2.4; however, version 25.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: packaging>=20.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: pillow>=8 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.8)
# Requirement already satisfied: zipp>=3.1.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: packaging>=20.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: cycler>=0.10 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: numpy>=1.23 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
