# %%
pip install SeqIO
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting SeqIO
#   Downloading seqio-0.0.19-py3-none-any.whl (354 kB)
#      |████████████████████████████████| 354 kB 2.4 MB/s eta 0:00:01
# Collecting absl-py
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 22.6 MB/s eta 0:00:01
# Collecting jax
#   Downloading jax-0.4.30-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 19.6 MB/s eta 0:00:01
# Collecting tfds-nightly==4.9.2.dev202308090034
#   Downloading tfds_nightly-4.9.2.dev202308090034-py3-none-any.whl (5.0 MB)
#      |████████████████████████████████| 5.0 MB 20.2 MB/s eta 0:00:01
# Collecting clu
#   Downloading clu-0.0.12-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 12.4 MB/s ta 0:00:01
# Collecting tensorflow-text
#   Downloading tensorflow_text-2.18.1-cp39-cp39-macosx_11_0_arm64.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 30.8 MB/s eta 0:00:01
# Collecting pyglove
#   Downloading pyglove-0.4.4-py3-none-any.whl (577 kB)
#      |████████████████████████████████| 577 kB 19.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from SeqIO) (2.0.2)
# Collecting jaxlib
#   Downloading jaxlib-0.4.30-cp39-cp39-macosx_11_0_arm64.whl (66.7 MB)
#      |████████████████████████████████| 66.7 MB 193 kB/s  eta 0:00:01
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp39-cp39-macosx_11_0_arm64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 18.5 MB/s eta 0:00:01
# Collecting protobuf<=3.20.3
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 12.6 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from SeqIO) (24.2)
# Collecting editdistance
#   Downloading editdistance-0.8.1-cp39-cp39-macosx_11_0_arm64.whl (79 kB)
#      |████████████████████████████████| 79 kB 19.0 MB/s eta 0:00:01
# Requirement already satisfied: psutil in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from tfds-nightly==4.9.2.dev202308090034->SeqIO) (6.1.1)
# Collecting dm-tree
#   Downloading dm_tree-0.1.8-cp39-cp39-macosx_11_0_arm64.whl (110 kB)
#      |████████████████████████████████| 110 kB 23.4 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.19.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from tfds-nightly==4.9.2.dev202308090034->SeqIO) (2.32.3)
# Requirement already satisfied: tqdm in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from tfds-nightly==4.9.2.dev202308090034->SeqIO) (4.67.1)
# Collecting click
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 15.7 MB/s eta 0:00:01
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-1.16.1-py3-none-any.whl (28 kB)
# Collecting etils[enp,epath,etree]>=0.9.0
#   Downloading etils-1.5.2-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 20.3 MB/s eta 0:00:01
# Collecting array-record
#   Downloading array_record-0.4.1-py39-none-any.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 18.9 MB/s eta 0:00:01
# Collecting promise
#   Downloading promise-2.3.tar.gz (19 kB)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting termcolor
#   Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Collecting wrapt
#   Downloading wrapt-1.17.2-cp39-cp39-macosx_11_0_arm64.whl (38 kB)
# Requirement already satisfied: zipp in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from etils[enp,epath,etree]>=0.9.0->tfds-nightly==4.9.2.dev202308090034->SeqIO) (3.21.0)
# Requirement already satisfied: importlib_resources in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from etils[enp,epath,etree]>=0.9.0->tfds-nightly==4.9.2.dev202308090034->SeqIO) (6.5.2)
# Collecting fsspec
#   Downloading fsspec-2025.2.0-py3-none-any.whl (184 kB)
#      |████████████████████████████████| 184 kB 20.0 MB/s eta 0:00:01
# Requirement already satisfied: typing_extensions in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from etils[enp,epath,etree]>=0.9.0->tfds-nightly==4.9.2.dev202308090034->SeqIO) (4.12.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->tfds-nightly==4.9.2.dev202308090034->SeqIO) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->tfds-nightly==4.9.2.dev202308090034->SeqIO) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->tfds-nightly==4.9.2.dev202308090034->SeqIO) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->tfds-nightly==4.9.2.dev202308090034->SeqIO) (2.3.0)
# Collecting flax
#   Downloading flax-0.8.5-py3-none-any.whl (731 kB)
#      |████████████████████████████████| 731 kB 22.0 MB/s eta 0:00:01
# Collecting ml-collections
#   Downloading ml_collections-0.1.1.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 18.2 MB/s eta 0:00:01
# Collecting optax
#   Downloading optax-0.2.4-py3-none-any.whl (319 kB)
#      |████████████████████████████████| 319 kB 19.9 MB/s eta 0:00:01
# Collecting orbax-checkpoint
#   Downloading orbax_checkpoint-0.6.4-py3-none-any.whl (270 kB)
#      |████████████████████████████████| 270 kB 23.9 MB/s eta 0:00:01
# Collecting msgpack
#   Downloading msgpack-1.1.0-cp39-cp39-macosx_11_0_arm64.whl (81 kB)
#      |████████████████████████████████| 81 kB 10.2 MB/s eta 0:00:01
# Collecting tensorstore
#   Downloading tensorstore-0.1.69-cp39-cp39-macosx_11_0_arm64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 24.7 MB/s eta 0:00:01
# Collecting rich>=11.1
#   Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 18.3 MB/s eta 0:00:01
# Collecting PyYAML>=5.4.1
#   Downloading PyYAML-6.0.2-cp39-cp39-macosx_11_0_arm64.whl (172 kB)
#      |████████████████████████████████| 172 kB 19.6 MB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from jax->SeqIO) (8.6.1)
# Collecting scipy>=1.9
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 14.1 MB/s eta 0:00:01
# Collecting ml-dtypes>=0.2.0
#   Downloading ml_dtypes-0.5.1-cp39-cp39-macosx_10_9_universal2.whl (667 kB)
#      |████████████████████████████████| 667 kB 13.1 MB/s eta 0:00:01
# Collecting opt-einsum
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 2.0 MB/s  eta 0:00:01
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 13.4 MB/s eta 0:00:01
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from rich>=11.1->flax->clu->SeqIO) (2.19.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from ml-collections->clu->SeqIO) (1.15.0)
# Collecting contextlib2
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting chex>=0.1.87
#   Downloading chex-0.1.88-py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 20.0 MB/s eta 0:00:01
# Collecting toolz>=0.9.0
#   Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 15.9 MB/s eta 0:00:01
# Collecting humanize
#   Downloading humanize-4.11.0-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 39.1 MB/s eta 0:00:01
# Requirement already satisfied: nest_asyncio in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from orbax-checkpoint->flax->clu->SeqIO) (1.6.0)
# Collecting docstring-parser>=0.12
#   Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Collecting tensorflow<2.19,>=2.18.0
#   Downloading tensorflow-2.18.0-cp39-cp39-macosx_12_0_arm64.whl (239.4 MB)
#      |████████████████████████████████| 239.4 MB 13.4 MB/s eta 0:00:01
# Collecting ml-dtypes>=0.2.0
#   Downloading ml_dtypes-0.4.1-cp39-cp39-macosx_10_9_universal2.whl (396 kB)
#      |████████████████████████████████| 396 kB 12.0 MB/s eta 0:00:01
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#      |████████████████████████████████| 25.8 MB 10.1 MB/s eta 0:00:01
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 10.3 MB/s eta 0:00:01
# Collecting h5py>=3.11.0
#   Downloading h5py-3.12.1-cp39-cp39-macosx_11_0_arm64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 10.1 MB/s eta 0:00:01
# Collecting flatbuffers>=24.3.25
#   Downloading flatbuffers-25.1.24-py2.py3-none-any.whl (30 kB)
# Collecting keras>=3.5.0
#   Downloading keras-3.8.0-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 13.0 MB/s eta 0:00:01
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.70.0-cp39-cp39-macosx_10_14_universal2.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 4.5 MB/s eta 0:00:01
# Collecting tensorboard<2.19,>=2.18
#   Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 6.8 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow<2.19,>=2.18.0->tensorflow-text->SeqIO) (58.0.4)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp39-cp39-macosx_12_0_arm64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 7.7 MB/s eta 0:00:01
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow<2.19,>=2.18.0->tensorflow-text->SeqIO) (0.37.0)
# Collecting optree
#   Downloading optree-0.14.0-cp39-cp39-macosx_11_0_arm64.whl (324 kB)
#      |████████████████████████████████| 324 kB 10.6 MB/s eta 0:00:01
# Collecting namex
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 9.9 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      |████████████████████████████████| 224 kB 7.5 MB/s eta 0:00:01
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl (12 kB)
# Building wheels for collected packages: ml-collections, promise
#   Building wheel for ml-collections (setup.py) ... done
#   Created wheel for ml-collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94524 sha256=f447332d507e13825a77fc6a12531430a604daa0c1767ede03630b8c42a0f4fd
#   Stored in directory: /Users/archiehogan/Library/Caches/pip/wheels/fd/c2/0d/5d94d95e5875ea17b85a9f1f99b8dd2e50517137c8042c6468
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21502 sha256=e41186a0695b207dbaa40e20cb0f16b917fd5a3c7b1bc3a60db1609a8c0eabf9
#   Stored in directory: /Users/archiehogan/Library/Caches/pip/wheels/e1/e8/83/ddea66100678d139b14bc87692ece57c6a2a937956d2532608
# Successfully built ml-collections promise
# Installing collected packages: scipy, ml-dtypes, opt-einsum, mdurl, jaxlib, etils, toolz, MarkupSafe, markdown-it-py, jax, fsspec, absl-py, werkzeug, tensorstore, tensorboard-data-server, rich, PyYAML, protobuf, optree, namex, msgpack, markdown, humanize, h5py, grpcio, chex, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorboard, orbax-checkpoint, optax, libclang, keras, google-pasta, gast, flatbuffers, contextlib2, astunparse, toml, tensorflow-metadata, tensorflow, promise, ml-collections, flax, docstring-parser, dm-tree, click, array-record, tfds-nightly, tensorflow-text, sentencepiece, pyglove, editdistance, clu, SeqIO
# Successfully installed MarkupSafe-3.0.2 PyYAML-6.0.2 SeqIO-0.0.19 absl-py-2.1.0 array-record-0.4.1 astunparse-1.6.3 chex-0.1.88 click-8.1.8 clu-0.0.12 contextlib2-21.6.0 dm-tree-0.1.8 docstring-parser-0.16 editdistance-0.8.1 etils-1.5.2 flatbuffers-25.1.24 flax-0.8.5 fsspec-2025.2.0 gast-0.6.0 google-pasta-0.2.0 grpcio-1.70.0 h5py-3.12.1 humanize-4.11.0 jax-0.4.30 jaxlib-0.4.30 keras-3.8.0 libclang-18.1.1 markdown-3.7 markdown-it-py-3.0.0 mdurl-0.1.2 ml-collections-0.1.1 ml-dtypes-0.4.1 msgpack-1.1.0 namex-0.0.8 opt-einsum-3.4.0 optax-0.2.4 optree-0.14.0 orbax-checkpoint-0.6.4 promise-2.3 protobuf-3.20.3 pyglove-0.4.4 rich-13.9.4 scipy-1.13.1 sentencepiece-0.2.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow-2.18.0 tensorflow-io-gcs-filesystem-0.37.1 tensorflow-metadata-1.16.1 tensorflow-text-2.18.1 tensorstore-0.1.69 termcolor-2.5.0 tfds-nightly-4.9.2.dev202308090034 toml-0.10.2 toolz-1.0.0 werkzeug-3.1.3 wrapt-1.17.2
# WARNING: You are using pip version 21.2.4; however, version 25.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bio 

pip install
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting bio
#   Downloading bio-1.6.2-py3-none-any.whl (278 kB)
#      |████████████████████████████████| 278 kB 2.9 MB/s eta 0:00:01
# Collecting gprofiler-official
#   Downloading gprofiler_official-1.0.0-py3-none-any.whl (9.3 kB)
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 16.7 MB/s eta 0:00:01
# Collecting mygene
#   Downloading mygene-3.2.2-py2.py3-none-any.whl (5.4 kB)
# Collecting biopython>=1.80
#   Downloading biopython-1.85-cp39-cp39-macosx_11_0_arm64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 19.4 MB/s eta 0:00:01
# Collecting pooch
#   Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 5.0 MB/s eta 0:00:011
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 18.0 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from bio) (2.2.3)
# Requirement already satisfied: numpy in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from biopython>=1.80->bio) (2.0.2)
# Collecting biothings-client>=0.2.6
#   Downloading biothings_client-0.4.1-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 15.2 MB/s eta 0:00:01
# Collecting httpx>=0.22.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 12.5 MB/s eta 0:00:01
# Collecting idna
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 31.1 MB/s eta 0:00:01
# Collecting anyio
#   Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 8.8 MB/s  eta 0:00:01
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 25.2 MB/s eta 0:00:01
# Collecting certifi
#   Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 38.4 MB/s eta 0:00:01
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 26.9 MB/s eta 0:00:01
# Requirement already satisfied: typing_extensions>=4.5 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->bio) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->bio) (1.2.2)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: tzdata>=2022.7 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from pandas->bio) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from pandas->bio) (2025.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from pandas->bio) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->bio) (1.15.0)
# Requirement already satisfied: packaging>=20.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from pooch->bio) (24.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/archiehogan/Library/Python/3.9/lib/python/site-packages (from pooch->bio) (4.3.6)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 26.5 MB/s eta 0:00:01
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.1-cp39-cp39-macosx_10_9_universal2.whl (197 kB)
#      |████████████████████████████████| 197 kB 31.5 MB/s eta 0:00:01
# Installing collected packages: sniffio, idna, h11, certifi, httpcore, anyio, urllib3, httpx, charset-normalizer, requests, biothings-client, tqdm, pooch, mygene, gprofiler-official, biopython, bio
# Successfully installed anyio-4.8.0 bio-1.6.2 biopython-1.85 biothings-client-0.4.1 certifi-2025.1.31 charset-normalizer-3.4.1 gprofiler-official-1.0.0 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 idna-3.10 mygene-3.2.2 pooch-1.8.2 requests-2.32.3 sniffio-1.3.1 tqdm-4.67.1 urllib3-2.3.0
# WARNING: You are using pip version 21.2.4; however, version 25.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import Bio 
from Bio import SeqIO
import os 
import glob 



def get_reference_order(reference_fasta):
    return [record.id for record in SeqIO.parse(reference_fasta, "fasta")]

def reorder_fasta(input_fasta, reference_order, output_fasta):
    seq_dict = {record.id: record for record in SeqIO.parse(input_fasta, "fasta")}
    ordered_records = [seq_dict[gene] for gene in reference_order if gene in seq_dict]
    SeqIO.write(ordered_records, output_fasta, "fasta")

def process_fasta_files(fasta_files, reference_fasta, output_dir="reordered_fastas"):
    os.makedirs(output_dir, exist_ok=True) 
    reference_order = get_reference_order(reference_fasta)

    for fasta_file in fasta_files: 
        output_fasta = os.path.join(output_dir, os.path.basename(fasta_file))
        reorder_fasta(fasta_file, reference_order, output_fasta)
        

fasta_files = glob.glob("../workdir/C.fasta/*.fas")
reference_fasta = "../workdir/C.fasta/57AT.fas"
process_fasta_files(fasta_files, reference_fasta)

print(reference_fasta)
# Out:
# ../workdir/C.fasta/57AT.fas
